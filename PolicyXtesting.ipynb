# %%
# Dependencies

import pandas as pd
import matplotlib
from sqlalchemy import create_engine

# %%
# CSV files that are being analyzed

policy_csv = "Resources/Data/Policy.csv"
policy_df = pd.read_csv(policy_csv)
policy_df.head()
# Out:
#    policy_id country         type                      gov_policy  \
# 0          1   Korea        Alert  Infectious Disease Alert Level
# 1          2   Korea        Alert  Infectious Disease Alert Level
# 2          3   Korea        Alert  Infectious Disease Alert Level
# 3          4   Korea        Alert  Infectious Disease Alert Level
# 4          5   Korea  Immigration   Special Immigration Procedure
#
#              detail  start_date    end_date
# 0    Level 1 (Blue)  2020-01-03  2020-01-19
# 1  Level 2 (Yellow)  2020-01-20  2020-01-27
# 2  Level 3 (Orange)  2020-01-28  2020-02-22
# 3     Level 4 (Red)  2020-02-23         NaN
# 4        from China  2020-02-04         NaN

# %%
testing_csv = "Resources/Data/Time.csv"
testing_df = pd.read_csv(testing_csv)
testing_df.head()
# Out:
#          date  time  test  negative  confirmed  released  deceased
# 0  2020-01-20    16     1         0          1         0         0
# 1  2020-01-21    16     1         0          1         0         0
# 2  2020-01-22    16     4         3          1         0         0
# 3  2020-01-23    16    22        21          1         0         0
# 4  2020-01-24    16    27        25          2         0         0

# %%
# New DataFrame for Policy.csv

new_policy = policy_df[["policy_id", "type", "detail", "start_date"]].copy()
policy_c = new_policy.rename(columns={"start_date": "date"})
policy_c
# Out:
#     policy_id            type  \
# 0           1           Alert
# 1           2           Alert
# 2           3           Alert
# 3           4           Alert
# 4           5     Immigration
# ..        ...             ...
# 56         57  Transformation
# 57         58  Transformation
# 58         59  Transformation
# 59         60      Technology
# 60         61          Health
#
#                                                detail        date
# 0                                      Level 1 (Blue)  2020-01-03
# 1                                    Level 2 (Yellow)  2020-01-20
# 2                                    Level 3 (Orange)  2020-01-28
# 3                                       Level 4 (Red)  2020-02-23
# 4                                          from China  2020-02-04
# ..                                                ...         ...
# 56  On-site inspection of major logistics faciliti...  2020-05-29
# 57  Mandatory wearing of passenger mask domestic, ...  2020-05-27
# 58  Drivers such as buses and taxis can refuse to ...  2020-05-26
# 59  new quick response (QR) code system this week ...  2020-06-10
# 60  Gov't Extends Tightened Quarantine Measures in...  2020-05-28
#
# [61 rows x 4 columns]

# %%
# New dataFrame for time.csv (testing)

new_testing = testing_df[["date", "test", "negative", "confirmed", "released", "deceased"]].copy()
new_testing
# Out:
#            date     test  negative  confirmed  released  deceased
# 0    2020-01-20        1         0          1         0         0
# 1    2020-01-21        1         0          1         0         0
# 2    2020-01-22        4         3          1         0         0
# 3    2020-01-23       22        21          1         0         0
# 4    2020-01-24       27        25          2         0         0
# ..          ...      ...       ...        ...       ...       ...
# 158  2020-06-26  1232315   1200885      12602     11172       282
# 159  2020-06-27  1243780   1211261      12653     11317       282
# 160  2020-06-28  1251695   1219975      12715     11364       282
# 48  2020-04-20   563035    540380      10674      8114       236
# 49  2020-04-20   563035    540380      10674      8114       236
# 50  2020-04-27   601660    582027      10738      8764       243
# 51  2020-05-06   643095    624280      10806      9333       255
# 52  2020-05-08   654863    635174      10822      9484       256
# 53  2020-05-16   740645    711265      11037      9851       262
# 54  2020-05-21   788684    759473      11122     10135       264
# 55  2020-05-26   839475    806206      11225     10275       269
# 56  2020-05-27   852876    820550      11265     10295       269
# 57  2020-05-28   868666    834952      11344     10340       269
# 58  2020-05-29   885120    849161      11402     10363       269
# 59  2020-06-10  1051972   1013847      11902     10611       276
#
#               type                                             detail
# 0            Alert                                   Level 2 (Yellow)
# 1       Technology                               Patients Information
# 2            Alert                                   Level 3 (Orange)
# 3      Immigration                                         from China
# 4           Health                                            1st EUA
# 5      Immigration                                     from Hong Kong
# 6      Immigration                                         from Macau
# 7           Health                                            2nd EUA
# 8       Technology                                                NaN
# 9            Alert                                      Level 4 (Red)
# 10          Health                                by Local Government
# 11          Health                                            3rd EUA
# 12          Health                                            4th EUA
# 13          Health                                        Public-Sale
# 14          Social                                             Strong
# 15       Education                        Daycare Center for Children
# 16       Education                                       Kindergarten
# 17       Education                                        High School
# 18       Education                                      Middle School
# 19       Education                                  Elementary School
# 20          Health                      Standard Operating Procedures
# 21      Technology                                                NaN
# 22      Technology                      Public Mask Sales Information
# 23     Immigration                                         from Japan
# 24          Health                              5-day Rotation System
# 25     Immigration                                         from Italy
# 26     Immigration                                          from Iran
# 27          Health                                            5th EUA
# 28     Immigration                                        from France
# 29     Immigration                                       from Germany
# 30     Immigration                                         from Spain
# 31     Immigration                                          from U.K.
# 32     Immigration                                   from Netherlands
# 33     Immigration                                        from Europe
# 34     Immigration                             from all the countries
# 35          Social                                             Strong
# 36     Immigration                             from all the countries
# 37       Education                            High School (3rd grade)
# 38       Education                          Middle School (3rd grade)
# 39     Immigration                                          from U.S.
# 40          Social                        Relay Cheer Campaign in SNS
# 41       Education                            High School (2nd grade)
# 42       Education                            High School (1st grade)
# 43       Education                          Middle School (2nd grade)
# 44       Education                          Middle School (1st grade)
# 45       Education                Elementary School (5th ~ 6th grade)
# 46       Education                      Elementary School (4th grade)
# 47          Social                                               Weak
# 48       Education                      Elementary School (3rd grade)
# 49       Education                Elementary School (1st ~ 2nd grade)
# 50      Technology     on people who violate self-quarantine measures
# 51          Social                                          Weak(1st)
# 52  Administrative       administrative order to close bars and clubs
# 53  Administrative  Gathering limited administrative orders for nu...
# 54  Administrative  Ban on gathering for 2 weeks for all karaoke a...
# 55  Transformation  Drivers such as buses and taxis can refuse to ...
# 56  Transformation  Mandatory wearing of passenger mask domestic, ...
# 57          Health  Gov't Extends Tightened Quarantine Measures in...
# 58  Transformation  On-site inspection of major logistics faciliti...
# 59      Technology  new quick response (QR) code system this week ...
