# %% [markdown]
# # 1. Analysis of the testing rate in comparison with the implementation of safety policies in South Korea

# %%
# Dependencies

import pandas as pd
import pandasql as ps
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine, func

# %% [markdown]
# ## Cleaning the data

# %%
# CSV files that are being analyzed

policy_csv = "Resources/Data/Policy.csv"
policy_df = pd.read_csv(policy_csv)
policy_df.head()
# Out:
#    policy_id country         type                      gov_policy  \
# 0          1   Korea        Alert  Infectious Disease Alert Level
# 1          2   Korea        Alert  Infectious Disease Alert Level
# 2          3   Korea        Alert  Infectious Disease Alert Level
# 3          4   Korea        Alert  Infectious Disease Alert Level
# 4          5   Korea  Immigration   Special Immigration Procedure
#
#              detail  start_date    end_date
# 0    Level 1 (Blue)  2020-01-03  2020-01-19
# 1  Level 2 (Yellow)  2020-01-20  2020-01-27
# 2  Level 3 (Orange)  2020-01-28  2020-02-22
# 3     Level 4 (Red)  2020-02-23         NaN
# 4        from China  2020-02-04         NaN

# %%
testing_csv = "Resources/Data/Time.csv"
testing_df = pd.read_csv(testing_csv)
testing_df.head()
# Out:
#          date  time  test  negative  confirmed  released  deceased
# 0  2020-01-20    16     1         0          1         0         0
# 1  2020-01-21    16     1         0          1         0         0
# 2  2020-01-22    16     4         3          1         0         0
# 3  2020-01-23    16    22        21          1         0         0
# 4  2020-01-24    16    27        25          2         0         0

# %%
# New DataFrame for Policy.csv

new_policy = policy_df[["policy_id", "type", "detail", "start_date"]].copy()
policy_c = new_policy.rename(columns={"start_date": "date"})
policy_c
# Out:
#     policy_id            type  \
# 0           1           Alert
# 1           2           Alert
# 2           3           Alert
# 3           4           Alert
# 4           5     Immigration
# ..        ...             ...
# 56         57  Transformation
# 57         58  Transformation
# 58         59  Transformation
# 59         60      Technology
# 60         61          Health
#
#                                                detail        date
# 0                                      Level 1 (Blue)  2020-01-03
# 1                                    Level 2 (Yellow)  2020-01-20
# 2                                    Level 3 (Orange)  2020-01-28
# 3                                       Level 4 (Red)  2020-02-23
# 4                                          from China  2020-02-04
# ..                                                ...         ...
# 56  On-site inspection of major logistics faciliti...  2020-05-29
# 57  Mandatory wearing of passenger mask domestic, ...  2020-05-27
# 58  Drivers such as buses and taxis can refuse to ...  2020-05-26
# 59  new quick response (QR) code system this week ...  2020-06-10
# 60  Gov't Extends Tightened Quarantine Measures in...  2020-05-28
#
# [61 rows x 4 columns]

# %%
# New dataFrame for time.csv (testing)

new_testing = testing_df[["date", "test", "negative", "confirmed", "released", "deceased"]].copy()
new_testing
# Out:
#            date     test  negative  confirmed  released  deceased
# 0    2020-01-20        1         0          1         0         0
# 1    2020-01-21        1         0          1         0         0
# 2    2020-01-22        4         3          1         0         0
# 3    2020-01-23       22        21          1         0         0
# 4    2020-01-24       27        25          2         0         0
# ..          ...      ...       ...        ...       ...       ...
# 158  2020-06-26  1232315   1200885      12602     11172       282
# 159  2020-06-27  1243780   1211261      12653     11317       282
# 160  2020-06-28  1251695   1219975      12715     11364       282
# 161  2020-06-29  1259954   1228698      12757     11429       282
# 162  2020-06-30  1273766   1240157      12800     11537       282
#
# [163 rows x 6 columns]

# %% [markdown]
# ### The table below, displays an average count of both confirmed and negative test results, as well as the number of patients that have been released, and the ones that have deceased. This allows us to see the effects of the implementation of policies to the virus testing rate.

# %%
# (Set both dataframes into one, and clean it up)

avgresults_df = pd.merge(left=new_testing, right=policy_c, left_on='date', right_on='date')
del avgresults_df["policy_id"]
avgresults_df.head()
# Out:
#          date  test  negative  confirmed  released  deceased         type  \
# 0  2020-01-20     1         0          1         0         0        Alert
# 1  2020-01-20     1         0          1         0         0   Technology
# 2  2020-01-28   116        97          4         0         0        Alert
# 3  2020-02-04   607       462         16         0         0  Immigration
# 4  2020-02-04   607       462         16         0         0       Health
#
#                  detail
# 0      Level 2 (Yellow)
# 1  Patients Information
# 2      Level 3 (Orange)
# 3            from China
# 4               1st EUA

# %%
clean_avgresults = avgresults_df.drop_duplicates(subset=['date'])
clean_results = clean_avgresults.dropna()
clean_results.head()
# Out:
#          date   test  negative  confirmed  released  deceased         type  \
# 0  2020-01-20      1         0          1         0         0        Alert
# 2  2020-01-28    116        97          4         0         0        Alert
# 3  2020-02-04    607       462         16         0         0  Immigration
# 5  2020-02-12   5624      4811         28         7         0  Immigration
# 9  2020-02-23  26179     17520        602        18         6        Alert
#
#              detail
# 0  Level 2 (Yellow)
# 2  Level 3 (Orange)
# 3        from China
# 5    from Hong Kong
# 9     Level 4 (Red)

# %% [markdown]
# ## Setup connection between SQL and pandas

# %%
rds_connection_string = "postgres:postgres@localhost:5432/etl_project"

engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['testingpolicies']

# %%
# upload data to sql database
clean_results.to_sql(name='testingpolicies', con=engine, if_exists='append', index=False)

# %%
# Read updated database from SQL
pd.read_sql_query('SELECT * FROM testingpolicies', con = engine).head()
# Out:
#          date   test  negative  confirmed  released  deceased         type  \
# 0  2020-01-20      1         0          1         0         0        Alert
# 1  2020-01-28    116        97          4         0         0        Alert
# 2  2020-02-04    607       462         16         0         0  Immigration
# 3  2020-02-12   5624      4811         28         7         0  Immigration
# 4  2020-02-23  26179     17520        602        18         6        Alert
#
#              detail
# 0  Level 2 (Yellow)
# 1  Level 3 (Orange)
# 2        from China
# 3    from Hong Kong
# 4     Level 4 (Red)

# %%
# policies query: look at the amount of policies implemented

p_qr = """SELECT type, detail FROM clean_results"""
print(ps.sqldf(p_qr,locals()))
# Out:
#               type                                             detail
# 0            Alert                                   Level 2 (Yellow)
# 1            Alert                                   Level 3 (Orange)
# 2      Immigration                                         from China
# 3      Immigration                                     from Hong Kong
# 4            Alert                                      Level 4 (Red)
# 5           Health                                by Local Government
# 6           Health                                            3rd EUA
# 7           Social                                             Strong
# 8        Education                        Daycare Center for Children
# 9           Health                      Standard Operating Procedures
# 10      Technology                      Public Mask Sales Information
# 11     Immigration                                         from Japan
# 12     Immigration                                         from Italy
# 13          Health                                            5th EUA
# 14     Immigration                                        from France
# 15     Immigration                                        from Europe
# 16     Immigration                             from all the countries
# 17          Social                                             Strong
# 18     Immigration                             from all the countries
# 19       Education                            High School (3rd grade)
# 20     Immigration                                          from U.S.
# 21          Social                        Relay Cheer Campaign in SNS
# 22          Social                                               Weak
# 23      Technology     on people who violate self-quarantine measures
# 24          Social                                          Weak(1st)
# 25  Administrative       administrative order to close bars and clubs
# 26  Administrative  Gathering limited administrative orders for nu...
# 27  Administrative  Ban on gathering for 2 weeks for all karaoke a...
# 28  Transformation  Drivers such as buses and taxis can refuse to ...
# 29  Transformation  Mandatory wearing of passenger mask domestic, ...
# 30          Health  Gov't Extends Tightened Quarantine Measures in...
# 31  Transformation  On-site inspection of major logistics faciliti...
# 32      Technology  new quick response (QR) code system this week ...

# %%
# Rate and count of positive and negative results based on the date of policies implementation 
test_results =  ps.sqldf("SELECT test, negative, confirmed, date, detail FROM clean_results")
test_results.head(20)
# Out:
#       test  negative  confirmed        date                         detail
# 0        1         0          1  2020-01-20               Level 2 (Yellow)
# 1      116        97          4  2020-01-28               Level 3 (Orange)
# 2      607       462         16  2020-02-04                     from China
# 3     5624      4811         28  2020-02-12                 from Hong Kong
# 4    26179     17520        602  2020-02-23                  Level 4 (Red)
# 5    53553     31576       1261  2020-02-26            by Local Government
# 6    66652     39318       1766  2020-02-27                        3rd EUA
# 7    94055     55723       3150  2020-02-29                         Strong
# 8   109591     71580       4212  2020-03-02    Daycare Center for Children
# 9   136707    102965       5328  2020-03-04  Standard Operating Procedures
# 10  188518    162008       7134  2020-03-08  Public Mask Sales Information
# 11  196618    171778       7382  2020-03-09                     from Japan
# 12  234998    209402       7869  2020-03-12                     from Italy
# 13  248647    222728       7979  2020-03-13                        5th EUA
# 14  268212    243778       8126  2020-03-15                    from France
# 15  274504    251297       8236  2020-03-16                    from Europe
# 16  307024    282555       8565  2020-03-19         from all the countries
# 17  331780    308343       8897  2020-03-22                         Strong
# 18  421547    395075       9887  2020-04-01         from all the countries
# 19  494711    468779      10423  2020-04-09        High School (3rd grade)

# %%
# Number of released and deceased patients, based on the policies implementation date
release_qr = ps.sqldf('SELECT test, released, deceased, date FROM clean_results')
release_qr.head(20)
# Out:
#       test  released  deceased        date
# 0        1         0         0  2020-01-20
# 1      116         0         0  2020-01-28
# 2      607         0         0  2020-02-04
# 3     5624         7         0  2020-02-12
# 4    26179        18         6  2020-02-23
# 5    53553        24        12  2020-02-26
# 6    66652        26        13  2020-02-27
# 7    94055        28        17  2020-02-29
# 8   109591        31        22  2020-03-02
# 9   136707        41        32  2020-03-04
# 10  188518       130        50  2020-03-08
# 11  196618       166        51  2020-03-09
# 12  234998       333        66  2020-03-12
# 13  248647       510        67  2020-03-13
# 14  268212       834        75  2020-03-15
# 15  274504      1137        75  2020-03-16
# 16  307024      1947        91  2020-03-19
# 17  331780      2909       104  2020-03-22
# 18  421547      5567       165  2020-04-01
# 19  494711      6973       204  2020-04-09

# %% [markdown]
# # 2. Comparison ratio of infection per region based on tracing of infection: group or individual.

# %%
# Read csv files
case_path = "Resources/Data/Case.csv"
Case = pd.read_csv(case_path)
# Print head of data
Case.head()
# Out:
#     case_id province          city  group               infection_case  \
# 0   1000001    Seoul    Yongsan-gu   True                Itaewon Clubs
# 1   1000002    Seoul     Gwanak-gu   True                      Richway
# 2   1000003    Seoul       Guro-gu   True          Guro-gu Call Center
# 3   1000004    Seoul  Yangcheon-gu   True  Yangcheon Table Tennis Club
# 4   1000005    Seoul     Dobong-gu   True              Day Care Center
#
#    confirmed   latitude   longitude
# 0        139  37.538621  126.992652
# 1        119   37.48208  126.901384
# 2         95  37.508163  126.884387
# 3         43  37.546061  126.874209
# 4         43  37.679422  127.044374

# %%
# Read csv files
region_path = "Resources/Data/Region.csv"
Region = pd.read_csv(region_path)
# Print data
Region
# Out:
#       code          province          city   latitude   longitude  \
# 0    10000             Seoul         Seoul  37.566953  126.977977
# 1    10010             Seoul    Gangnam-gu  37.518421  127.047222
# 2    10020             Seoul   Gangdong-gu  37.530492  127.123837
# 3    10030             Seoul    Gangbuk-gu  37.639938  127.025508
# 4    10040             Seoul    Gangseo-gu  37.551166  126.849506
# ..     ...               ...           ...        ...         ...
# 239  61160  Gyeongsangnam-do     Haman-gun  35.272481  128.406540
# 240  61170  Gyeongsangnam-do   Hamyang-gun  35.520541  127.725177
# 241  61180  Gyeongsangnam-do  Hapcheon-gun  35.566702  128.165870
# 242  70000           Jeju-do       Jeju-do  33.488936  126.500423
# 243  80000             Korea         Korea  37.566953  126.977977
#
#      elementary_school_count  kindergarten_count  university_count  \
# 0                        607                 830                48
# 1                         33                  38                 0
# 2                         27                  32                 0
# 3                         14                  21                 0
# 4                         36                  56                 1
# ..                       ...                 ...               ...
# 239                       16                  20                 0
# 240                       13                  12                 0
# 241                       17                  15                 0
# 242                      113                 123                 4
# 243                     6087                8837               340
#
#      academy_ratio  elderly_population_ratio  elderly_alone_ratio  \
# 0             1.44                     15.38                  5.8
# 1             4.18                     13.17                  4.3
# 2             1.54                     14.55                  5.4
# 3             0.67                     19.49                  8.5
# 4             1.17                     14.39                  5.7
# ..             ...                       ...                  ...
# 239           1.19                     23.74                 14.7
# 240           1.01                     32.65                 20.9
# 241           0.71                     38.44                 24.7
# 242           1.53                     15.10                  6.4
# 243           1.56                     15.67                  7.2
#
#      nursing_home_count
# 0                 22739
# 1                  3088
# 2                  1023
# 3                   628
# 4                  1080
# ..                  ...
# 239                  94
# 240                  83
# 241                  96
# 242                1245
# 243               94865
#
# [244 rows x 12 columns]

# %%
Case.columns
# Out:
# Index(['code', 'province', 'city', 'latitude', 'longitude',
#        'elementary_school_count', 'kindergarten_count', 'university_count',
#        'academy_ratio', 'elderly_population_ratio', 'elderly_alone_ratio',
#        'nursing_home_count'],
#       dtype='object')

# %%
Region.columns
# Out:
# Index(['code', 'province', 'city', 'latitude', 'longitude',
#        'elementary_school_count', 'kindergarten_count', 'university_count',
#        'academy_ratio', 'elderly_population_ratio', 'elderly_alone_ratio',
#        'nursing_home_count'],
#       dtype='object')

# %%
# Merge dataframes based on City name
CompleteDataDFCity = pd.merge(Case, Region, how ="left", on = ["city", "city"])

CompleteDataDFCity
# Out:
#       case_id        province_x             city  group  \
# 0     1000001             Seoul       Yongsan-gu   True
# 1     1000002             Seoul        Gwanak-gu   True
# 2     1000003             Seoul          Guro-gu   True
# 3     1000004             Seoul     Yangcheon-gu   True
# 4     1000005             Seoul        Dobong-gu   True
# ..        ...               ...              ...    ...
# 218   6100012  Gyeongsangnam-do                -  False
# 219   7000001           Jeju-do                -  False
# 220   7000002           Jeju-do                -  False
# 221   7000003           Jeju-do                -  False
# 222   7000004           Jeju-do  from other city   True
#
#                   infection_case  confirmed latitude_x longitude_x     code  \
# 0                  Itaewon Clubs        139  37.538621  126.992652  10210.0
# 1                        Richway        119   37.48208  126.901384  10050.0
# 2            Guro-gu Call Center         95  37.508163  126.884387  10070.0
# 3    Yangcheon Table Tennis Club         43  37.546061  126.874209  10190.0
# 4                Day Care Center         43  37.679422  127.044374  10100.0
# ..                           ...        ...        ...         ...      ...
# 218                          etc         20          -           -      NaN
# 219              overseas inflow         14          -           -      NaN
# 220         contact with patient          0          -           -      NaN
# 221                          etc          4          -           -      NaN
# 222                Itaewon Clubs          1          -           -      NaN
#
#     province_y  latitude_y  longitude_y  elementary_school_count  \
# 0        Seoul   37.532768   126.990021                     15.0
# 1        Seoul   37.478290   126.951502                     22.0
# 2        Seoul   37.495632   126.887650                     26.0
# 3        Seoul   37.517189   126.866618                     30.0
# 4        Seoul   37.668952   127.047082                     23.0
# ..         ...         ...          ...                      ...
# 218        NaN         NaN          NaN                      NaN
# 219        NaN         NaN          NaN                      NaN
# 220        NaN         NaN          NaN                      NaN
# 221        NaN         NaN          NaN                      NaN
# 222        NaN         NaN          NaN                      NaN
#
#      kindergarten_count  university_count  academy_ratio  \
# 0                  13.0               1.0           0.68
# 1                  33.0               1.0           0.89
# 2                  34.0               3.0           1.00
# 3                  43.0               0.0           2.26
# 4                  26.0               1.0           0.95
# ..                  ...               ...            ...
# 218                 NaN               NaN            NaN
# 219                 NaN               NaN            NaN
# 220                 NaN               NaN            NaN
# 221                 NaN               NaN            NaN
# 222                 NaN               NaN            NaN
#
#      elderly_population_ratio  elderly_alone_ratio  nursing_home_count
# 0                       16.87                  6.5               435.0
# 1                       15.12                  4.9               909.0
# 2                       16.21                  5.7               741.0
# 3                       13.55                  5.5               816.0
# 4                       17.89                  7.2               485.0
# ..                        ...                  ...                 ...
# 218                       NaN                  NaN                 NaN
# 219                       NaN                  NaN                 NaN
# 220                       NaN                  NaN                 NaN
# 221                       NaN                  NaN                 NaN
# 222                       NaN                  NaN                 NaN
#
# [223 rows x 19 columns]

# %%
# Clean merged Data
CleanDF = CompleteDataDFCity[["city", "group", "infection_case", "confirmed", "code"]].copy()
CleanDF
# Out:
#                 city  group               infection_case  confirmed     code
# 0         Yongsan-gu   True                Itaewon Clubs        139  10210.0
# 1          Gwanak-gu   True                      Richway        119  10050.0
# 2            Guro-gu   True          Guro-gu Call Center         95  10070.0
# 3       Yangcheon-gu   True  Yangcheon Table Tennis Club         43  10190.0
# 4          Dobong-gu   True              Day Care Center         43  10100.0
# ..               ...    ...                          ...        ...      ...
# 218                -  False                          etc         20      NaN
# 219                -  False              overseas inflow         14      NaN
# 220                -  False         contact with patient          0      NaN
# 221                -  False                          etc          4      NaN
# 222  from other city   True                Itaewon Clubs          1      NaN
#
# [223 rows x 5 columns]

# %%
# drop NAn Values
CleanDF.replace(np.nan, 0, inplace=True)
CleanDF
# Out:
#                 city  group               infection_case  confirmed     code
# 0         Yongsan-gu   True                Itaewon Clubs        139  10210.0
# 1          Gwanak-gu   True                      Richway        119  10050.0
# 2            Guro-gu   True          Guro-gu Call Center         95  10070.0
# 3       Yangcheon-gu   True  Yangcheon Table Tennis Club         43  10190.0
# 4          Dobong-gu   True              Day Care Center         43  10100.0
# ..               ...    ...                          ...        ...      ...
# 218                -  False                          etc         20      0.0
# 219                -  False              overseas inflow         14      0.0
# 220                -  False         contact with patient          0      0.0
# 221                -  False                          etc          4      0.0
# 222  from other city   True                Itaewon Clubs          1      0.0
#
# [223 rows x 5 columns]

# %%
# Reassuring table is clean
CleanDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 223 entries, 0 to 222
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            223 non-null    object
#  1   group           223 non-null    bool
#  2   infection_case  223 non-null    object
#  3   confirmed       223 non-null    int64
#  4   code            223 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(2)
# memory usage: 8.9+ KB

# %%
# Drop duplicates in code column
CleanDF_bis = CleanDF.drop_duplicates(subset = ["code"])
CleanDF_biss = CleanDF_bis.drop_duplicates(subset = ["city"])
Cleancheck = CleanDF_biss.dropna()
Cleancheck.head()
# Out:
#            city  group               infection_case  confirmed     code
# 0    Yongsan-gu   True                Itaewon Clubs        139  10210.0
# 1     Gwanak-gu   True                      Richway        119  10050.0
# 2       Guro-gu   True          Guro-gu Call Center         95  10070.0
# 3  Yangcheon-gu   True  Yangcheon Table Tennis Club         43  10190.0
# 4     Dobong-gu   True              Day Care Center         43  10100.0

# %%
# Uploading dataframe into SQL database
Cleancheck.to_sql(name='regions', con=engine, if_exists='append', index=False)

# %%
# Read updated db from SQL
pd.read_sql_query('SELECT * from regions', con=engine).head(20)
# Out:
#                city  group                                 infection_case  \
# 0        Yongsan-gu   True                                  Itaewon Clubs
# 1         Gwanak-gu   True                                        Richway
# 2           Guro-gu   True                            Guro-gu Call Center
# 3      Yangcheon-gu   True                    Yangcheon Table Tennis Club
# 4         Dobong-gu   True                                Day Care Center
# 5   from other city   True               SMR Newly Planted Churches Group
# 6     Dongdaemun-gu   True                                  Dongan Church
# 7      Eunpyeong-gu   True                  Eunpyeong St. Mary's Hospital
# 8      Seongdong-gu   True                               Seongdong-gu APT
# 9         Jongno-gu   True                        Jongno Community Center
# 10       Gangnam-gu   True                         Samsung Medical Center
# 11          Jung-gu   True                        Jung-gu Fashion Company
# 12     Seodaemun-gu   True                             Yeonana News Class
# 13     Geumcheon-gu   True  Geumcheon-gu rice milling machine manufacture
# 14  Yeongdeungpo-gu   True                Yeongdeungpo Learning Institute
# 15        Seocho-gu   True                                  Seocho Family
# 16       Gangseo-gu   True                      SJ Investment Call Center
# 17       Dongnae-gu   True                                  Onchun Church
# 18       Suyeong-gu   True                        Suyeong-gu Kindergarten
# 19      Haeundae-gu   True                    Haeundae-gu Catholic Church
#
#     confirmed     code
# 0         139  10210.0
# 1         119  10050.0
# 2          95  10070.0
# 3          43  10190.0
# 4          43  10100.0
# 5          36      0.0
# 6          17  10110.0
# 7          14  10220.0
# 8          13  10160.0
# 9          10  10230.0
# 10          7  10010.0
# 11          7  10240.0
# 12          5  10140.0
# 13          6  10080.0
# 14          3  10200.0
# 15          5  10150.0
# 16          0  10040.0
# 17         39  11060.0
# 18          5  11120.0
# 19          6  11160.0

# %%
# Perform query that shows whether an infection is a cluster or just an individual case
clusterqr= ps.sqldf("""SELECT infection_case, city FROM Cleancheck""")
clusterqr.head()
# Out:
#                 infection_case          city
# 0                Itaewon Clubs    Yongsan-gu
# 1                      Richway     Gwanak-gu
# 2          Guro-gu Call Center       Guro-gu
# 3  Yangcheon Table Tennis Club  Yangcheon-gu
# 4              Day Care Center     Dobong-gu

# %% [markdown]
# # 3. Analysis of COVID-19 confirmed cases in South Korea to determine which age group and gender was most affected. And trying to find if there is a clear distinction in ‘number of infections’ or ‘death rate’ between different age groups or genders, if there is one.

# %%
# Store CSV into DataFrame
csv_file = "Resources/Data/PatientInfo.csv"
patient_info_df = pd.read_csv(csv_file)
patient_info_df.head()
# Out:
#    patient_id     sex  age country province         city  \
# 0  1000000001    male  50s   Korea    Seoul   Gangseo-gu
# 1  1000000002    male  30s   Korea    Seoul  Jungnang-gu
# 2  1000000003    male  50s   Korea    Seoul    Jongno-gu
# 3  1000000004    male  20s   Korea    Seoul      Mapo-gu
# 4  1000000005  female  20s   Korea    Seoul  Seongbuk-gu
#
#          infection_case infected_by contact_number symptom_onset_date  \
# 0       overseas inflow         NaN             75         2020-01-22
# 1       overseas inflow         NaN             31                NaN
# 2  contact with patient  2002000001             17                NaN
# 3       overseas inflow         NaN              9         2020-01-26
# 4  contact with patient  1000000002              2                NaN
#
#   confirmed_date released_date deceased_date     state
# 0     2020-01-23    2020-02-05           NaN  released
# 1     2020-01-30    2020-03-02           NaN  released
# 2     2020-01-30    2020-02-19           NaN  released
# 3     2020-01-30    2020-02-15           NaN  released
# 4     2020-01-31    2020-02-24           NaN  released

# %%
patient_info_df.columns
# Out:
# Index(['patient_id', 'sex', 'age', 'country', 'province', 'city',
#        'infection_case', 'infected_by', 'contact_number', 'symptom_onset_date',
#        'confirmed_date', 'released_date', 'deceased_date', 'state'],
#       dtype='object')

# %%
# new DF with select columns

new_patient_info_df = patient_info_df[['patient_id', 'sex', 'age', 'province', 'city', \
                                       'confirmed_date', 'released_date', 'state']].copy()
new_patient_info_df
# Out:
#       patient_id     sex  age province         city confirmed_date  \
# 0     1000000001    male  50s    Seoul   Gangseo-gu     2020-01-23
# 1     1000000002    male  30s    Seoul  Jungnang-gu     2020-01-30
# 2     1000000003    male  50s    Seoul    Jongno-gu     2020-01-30
# 3     1000000004    male  20s    Seoul      Mapo-gu     2020-01-30
# 4     1000000005  female  20s    Seoul  Seongbuk-gu     2020-01-31
# ...          ...     ...  ...      ...          ...            ...
# 5160  7000000015  female  30s  Jeju-do      Jeju-do     2020-05-30
# 5161  7000000016     NaN  NaN  Jeju-do      Jeju-do     2020-06-16
# 5162  7000000017     NaN  NaN  Jeju-do      Jeju-do     2020-06-18
# 5163  7000000018     NaN  NaN  Jeju-do      Jeju-do     2020-06-18
# 5164  7000000019     NaN  NaN  Jeju-do      Jeju-do     2020-06-18
#
#      released_date     state
# 0       2020-02-05  released
# 1       2020-03-02  released
# 2       2020-02-19  released
# 3       2020-02-15  released
# 4       2020-02-24  released
# ...            ...       ...
# 5160    2020-06-13  released
# 5161    2020-06-24  released
# 5162           NaN  isolated
# 5163           NaN  isolated
# 5164           NaN  isolated
#
# [5165 rows x 8 columns]

# %% [markdown]
# # Clean DataFrame

# %%
# Replacing 'Nan' values with '0'
new_patient_info_df.fillna(0, inplace=True)

# %%
# Checking for null values in DataFrame
new_patient_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5165 entries, 0 to 5164
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      5165 non-null   int64
#  1   sex             5165 non-null   object
#  2   age             5165 non-null   object
#  3   province        5165 non-null   object
#  4   city            5165 non-null   object
#  5   confirmed_date  5165 non-null   object
#  6   released_date   5165 non-null   object
#  7   state           5165 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 322.9+ KB

# %%
# Checking for duplicates in a column
new_patient_info_df[new_patient_info_df["patient_id"].duplicated()]
# Out:
#       patient_id     sex  age province    city confirmed_date released_date  \
# 1555  1200012238  female  20s    Daegu  Nam-gu     2020-06-17             0
#
#          state
# 1555  isolated

# %%
# Locate the values that are duplicated and compare both the original and the copy
find = new_patient_info_df[new_patient_info_df['patient_id'].astype(str).str.contains('1200012238')]
find
# Out:
#       patient_id     sex  age province         city confirmed_date  \
# 1547  1200012238  female  20s    Daegu  Icheon-dong     2020-06-17
# 1555  1200012238  female  20s    Daegu       Nam-gu     2020-06-17
#
#      released_date     state
# 1547             0  isolated
# 1555             0  isolated

# %%
cleaned_info = new_patient_info_df.drop_duplicates(subset = ["patient_id"], keep=False)
cleaned_info
# Out:
#       patient_id     sex  age province         city confirmed_date  \
# 0     1000000001    male  50s    Seoul   Gangseo-gu     2020-01-23
# 1     1000000002    male  30s    Seoul  Jungnang-gu     2020-01-30
# 2     1000000003    male  50s    Seoul    Jongno-gu     2020-01-30
# 3     1000000004    male  20s    Seoul      Mapo-gu     2020-01-30
# 4     1000000005  female  20s    Seoul  Seongbuk-gu     2020-01-31
# ...          ...     ...  ...      ...          ...            ...
# 5160  7000000015  female  30s  Jeju-do      Jeju-do     2020-05-30
# 5161  7000000016       0    0  Jeju-do      Jeju-do     2020-06-16
# 5162  7000000017       0    0  Jeju-do      Jeju-do     2020-06-18
# 5163  7000000018       0    0  Jeju-do      Jeju-do     2020-06-18
# 5164  7000000019       0    0  Jeju-do      Jeju-do     2020-06-18
#
#      released_date     state
# 0       2020-02-05  released
# 1       2020-03-02  released
# 2       2020-02-19  released
# 3       2020-02-15  released
# 4       2020-02-24  released
# ...            ...       ...
# 5160    2020-06-13  released
# 5161    2020-06-24  released
# 5162             0  isolated
# 5163             0  isolated
# 5164             0  isolated
#
# [5163 rows x 8 columns]

# %%
# Upload the dataframe into the SQL database
cleaned_info.to_sql(name='patient_info', con=engine, if_exists='append', index=False)
