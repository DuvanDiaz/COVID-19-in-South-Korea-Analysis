# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
# Read csv files
TimeAge = pd.read_csv(r"C:\Users\eline\Documents\ETL project EVE\Resources\TimeAge.csv", header = None, skiprows = [0])
# Print head of data
TimeAge.head()
# Out:
#             0  1    2     3  4
# 0  2020-03-02  0   0s    32  0
# 1  2020-03-02  0  10s   169  0
# 2  2020-03-02  0  20s  1235  0
# 3  2020-03-02  0  30s   506  1
# 4  2020-03-02  0  40s   633  1

# %%
# Read csv files
Time = pd.read_csv(r"C:\Users\eline\Documents\ETL project EVE\Resources\Time.csv", header = None, skiprows = [0])
# Print head of data
Time.head()
# Out:
#             0   1   2   3  4  5  6
# 0  2020-01-20  16   1   0  1  0  0
# 1  2020-01-21  16   1   0  1  0  0
# 2  2020-01-22  16   4   3  1  0  0
# 3  2020-01-23  16  22  21  1  0  0
# 4  2020-01-24  16  27  25  2  0  0

# %%
# Read csv files
Case = pd.read_csv(r"C:\Users\eline\Documents\ETL project EVE\Resources\Case.csv")
# Print head of data
Case.head()
# Out:
#     case_id province          city  group               infection_case  \
# 0   1000001    Seoul    Yongsan-gu   True                Itaewon Clubs
# 1   1000002    Seoul     Gwanak-gu   True                      Richway
# 2   1000003    Seoul       Guro-gu   True          Guro-gu Call Center
# 3   1000004    Seoul  Yangcheon-gu   True  Yangcheon Table Tennis Club
# 4   1000005    Seoul     Dobong-gu   True              Day Care Center
#
#    confirmed   latitude   longitude
# 0        139  37.538621  126.992652
# 1        119   37.48208  126.901384
# 2         95  37.508163  126.884387
# 3         43  37.546061  126.874209
# 4         43  37.679422  127.044374

# %%
# Read csv file
Policy = pd.read_csv(r"C:\Users\eline\Documents\ETL project EVE\Resources\Policy.csv", header = None, skiprows = [0])
# Print head of data
Policy.head()
# Out:
#    0      1            2                               3                 4  \
# 0  1  Korea        Alert  Infectious Disease Alert Level    Level 1 (Blue)
# 1  2  Korea        Alert  Infectious Disease Alert Level  Level 2 (Yellow)
# 2  3  Korea        Alert  Infectious Disease Alert Level  Level 3 (Orange)
# 3  4  Korea        Alert  Infectious Disease Alert Level     Level 4 (Red)
# 4  5  Korea  Immigration   Special Immigration Procedure        from China
#
#             5           6
# 0  2020-01-03  2020-01-19
# 1  2020-01-20  2020-01-27
# 2  2020-01-28  2020-02-22
# 3  2020-02-23         NaN
# 4  2020-02-04         NaN

# %%
# Read csv files
TimeProvince = pd.read_csv(r"C:\Users\eline\Documents\ETL project EVE\Resources\TimeProvince.csv", header = None, skiprows = [0])
# Print head of data
TimeProvince.head()
# Out:
#             0   1        2  3  4  5
# 0  2020-01-20  16    Seoul  0  0  0
# 1  2020-01-20  16    Busan  0  0  0
# 2  2020-01-20  16    Daegu  0  0  0
# 3  2020-01-20  16  Incheon  1  0  0
# 4  2020-01-20  16  Gwangju  0  0  0

# %%
# Read csv files
Region = pd.read_csv(r"C:\Users\eline\Documents\ETL project EVE\Resources\Region.csv")
# Print data
Region
# Out:
#       code          province          city   latitude   longitude  \
# 0    10000             Seoul         Seoul  37.566953  126.977977
# 1    10010             Seoul    Gangnam-gu  37.518421  127.047222
# 2    10020             Seoul   Gangdong-gu  37.530492  127.123837
# 3    10030             Seoul    Gangbuk-gu  37.639938  127.025508
# 4    10040             Seoul    Gangseo-gu  37.551166  126.849506
# ..     ...               ...           ...        ...         ...
# 239  61160  Gyeongsangnam-do     Haman-gun  35.272481  128.406540
# 240  61170  Gyeongsangnam-do   Hamyang-gun  35.520541  127.725177
# 241  61180  Gyeongsangnam-do  Hapcheon-gun  35.566702  128.165870
# 242  70000           Jeju-do       Jeju-do  33.488936  126.500423
# 243  80000             Korea         Korea  37.566953  126.977977
#
#      elementary_school_count  kindergarten_count  university_count  \
# 0                        607                 830                48
# ...

# %%
Region.columns
# Out:
# Index(['code', 'province', 'city', 'latitude', 'longitude',
#        'elementary_school_count', 'kindergarten_count', 'university_count',
#        'academy_ratio', 'elderly_population_ratio', 'elderly_alone_ratio',
#        'nursing_home_count'],
#       dtype='object')

# %%
region_db = Region[['province', 'city', 'latitude','longitude']]
region_db
# Out:
#              province          city   latitude   longitude
# 0               Seoul         Seoul  37.566953  126.977977
# 1               Seoul    Gangnam-gu  37.518421  127.047222
# 2               Seoul   Gangdong-gu  37.530492  127.123837
# 3               Seoul    Gangbuk-gu  37.639938  127.025508
# 4               Seoul    Gangseo-gu  37.551166  126.849506
# ..                ...           ...        ...         ...
# 239  Gyeongsangnam-do     Haman-gun  35.272481  128.406540
# 240  Gyeongsangnam-do   Hamyang-gun  35.520541  127.725177
# 241  Gyeongsangnam-do  Hapcheon-gun  35.566702  128.165870
# 242           Jeju-do       Jeju-do  33.488936  126.500423
# 243             Korea         Korea  37.566953  126.977977
#
# [244 rows x 4 columns]

# %%
Case.columns
# Out:
# Index([' case_id', 'province', 'city', 'group', 'infection_case', 'confirmed',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
case_db = Case[[' case_id', 'province', 'city', 'infection_case', 'confirmed', 'latitude', 'longitude']]

# %%
case_db
# Out:
#       case_id          province             city               infection_case  \
# 0     1000001             Seoul       Yongsan-gu                Itaewon Clubs
# 1     1000002             Seoul        Gwanak-gu                      Richway
# 2     1000003             Seoul          Guro-gu          Guro-gu Call Center
# 3     1000004             Seoul     Yangcheon-gu  Yangcheon Table Tennis Club
# 4     1000005             Seoul        Dobong-gu              Day Care Center
# ..        ...               ...              ...                          ...
# 169   6100012  Gyeongsangnam-do                -                          etc
# 170   7000001           Jeju-do                -              overseas inflow
# 171   7000002           Jeju-do                -         contact with patient
# 172   7000003           Jeju-do                -                          etc
# 173   7000004           Jeju-do  from other city                Itaewon Clubs
#
# ...

# %%
# # Merge dataframes based on Province name
# CompleteDataDF = pd.merge(Case, Region, how ="left", on = ["province", "province"])
# # CompleteDataDF.drop(["longitude_x" ,"longitude_y", "latitude_x", "latitude_y", "elementary_school_count", "kindergarten_count", "university_count", "academy_ratio", "elderly_population_ratio", "elderly_alone_ratio", "nursing_home_count"], axis=1, inplace=True)



# CompleteDataDF

# CompleteDF.drop_duplicates = []

# %%
# # Merge dataframes based on Province name
CompleteDataDFCity = pd.merge(Case, Region, how ="left", on = ["city", "city"])

# CompleteDataDF.drop(["longitude_x" ,"longitude_y", "latitude_x", "latitude_y", "elementary_school_count", "kindergarten_count", "university_count", "academy_ratio", "elderly_population_ratio", "elderly_alone_ratio", "nursing_home_count"], axis=1, inplace=True)
CompleteDataDFCity
# Out:
#       case_id        province_x             city  group  \
# 0     1000001             Seoul       Yongsan-gu   True
# 1     1000002             Seoul        Gwanak-gu   True
# 2     1000003             Seoul          Guro-gu   True
# 3     1000004             Seoul     Yangcheon-gu   True
# 4     1000005             Seoul        Dobong-gu   True
# ..        ...               ...              ...    ...
# 218   6100012  Gyeongsangnam-do                -  False
# 219   7000001           Jeju-do                -  False
# 220   7000002           Jeju-do                -  False
# 221   7000003           Jeju-do                -  False
# 222   7000004           Jeju-do  from other city   True
#
#                   infection_case  confirmed latitude_x longitude_x     code  \
# 0                  Itaewon Clubs        139  37.538621  126.992652  10210.0
# 1                        Richway        119   37.48208  126.901384  10050.0
# ...

# %%
CleanDF = CompleteDataDFCity[["province_x", "city", "group", "infection_case", "confirmed", "code"]].copy()
CleanDF
# Out:
#            province_x             city  group               infection_case  \
# 0               Seoul       Yongsan-gu   True                Itaewon Clubs
# 1               Seoul        Gwanak-gu   True                      Richway
# 2               Seoul          Guro-gu   True          Guro-gu Call Center
# 3               Seoul     Yangcheon-gu   True  Yangcheon Table Tennis Club
# 4               Seoul        Dobong-gu   True              Day Care Center
# ..                ...              ...    ...                          ...
# 218  Gyeongsangnam-do                -  False                          etc
# 219           Jeju-do                -  False              overseas inflow
# 220           Jeju-do                -  False         contact with patient
# 221           Jeju-do                -  False                          etc
# 222           Jeju-do  from other city   True                Itaewon Clubs
#
#      confirmed     code
# 0          139  10210.0
# ...

# %%
GroupByDF = CompleteDataDFCity.groupby(" case_id")
# DropCaseID = [["province", "city_x", "group", "infection_case", "confirmed", "code", "city_y"]].copy()
GroupByDF.head()

# %%
# inplace
GroupByDF.replace(np.nan, 0, inplace=True)
